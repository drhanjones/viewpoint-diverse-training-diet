# %%
import viewpoint_diverse_training_diet.data_loader.data_loaders as module_data
import viewpoint_diverse_training_diet.metrics as module_metric

# %%
module_metric.accuracy(1,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 module_metric.accuracy(1,2)
#
# File ~/Projects/PhD/Code/viewpoint-diverse-training-diet/src/viewpoint_diverse_training_diet/metrics/metric.py:6, in accuracy(output, target)
#       4 def accuracy(output, target):
#       5     with torch.no_grad():
# ----> 6         pred = torch.argmax(output, dim=1)
#       7         assert pred.shape[0] == len(target)
#       8         correct = 0
#
# TypeError: argmax(): argument 'input' (position 1) must be Tensor, not int
